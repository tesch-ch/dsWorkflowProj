# %%
import pickle
import pandas as pd

# %%
# Load from nlp_collection_list.pkl
with open('nlp_collection_list.pkl', 'rb') as f:
    nlp_collection_list = pickle.load(f)

# %%
len(nlp_collection_list)
# Out:
# 2917

# %%
i = 3
nlp_collection_list[i]['title'], nlp_collection_list[i]['entities'], nlp_collection_list[i]['entities_verbose']
# Out:
# ('From Dumb Money to Saw X: 10 of the best films to watch in September',
#  ['Saw X'],
#  [{'entity_group': 'MISC',
#    'score': 0.6824857592582703,
#    'word': 'Du',
#    'start': 5,
#    'end': 7},
#   {'entity_group': 'MISC',
#    'score': 0.7616474032402039,
#    'word': 'Money',
#    'start': 10,
#    'end': 15},
#   {'entity_group': 'MISC',
#    'score': 0.9924801588058472,
#    'word': 'Saw X',
#    'start': 19,
#    'end': 24}])

# %%
# Convert to pandas dataframe
df = pd.DataFrame(nlp_collection_list)
df
# Out:
#                            _id source
# 0     64ebd5efb36280b9aa11e6e3    bbc  \
# 1     64ebd5efb36280b9aa11e6e4    bbc
# 2     64ebd5efb36280b9aa11e6e5    bbc
# 3     64ebd5f0b36280b9aa11e6e6    bbc
# 4     64ebd5f0b36280b9aa11e6e7    bbc
# ...                        ...    ...
# 2912  64f0301451778ebdd9218295    fox
# 2913  64f0301451778ebdd9218296    fox
# 2914  64f039319d1ee0810d1cbebb    fox
# 2915  64f039329d1ee0810d1cbebc    fox
# 2916  64f03a7a415f03587c4a97c2    cnn
#
#                                                     url
# 0     https://www.bbc.com/future/article/20230825-th...  \
# 1     https://www.bbc.com/worklife/article/20230824-...
# 2     https://www.bbc.com/travel/article/20230827-am...
# 3     https://www.bbc.com/culture/article/20230823-f...
# 4     https://www.bbc.com/future/article/20230825-th...
# ...                                                 ...
# 2912  https://www.foxnews.com/entertainment/meghan-m...
# ...

# %%
# show a few random rows
df.sample(5)

# %%
df.columns
# Out:
# Index(['_id', 'source', 'url', 'title', 'authors', 'top_image', 'text',
#        'timestamp', 'category', 'category_verbose', 'entities',
#        'entities_verbose'],
#       dtype='object')
